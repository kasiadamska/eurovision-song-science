# %% [markdown]
# ## Lyrics Feature Extraction
#
# Feature extraction from lyrics in original languages: analyzing vocabulary richness and repetitiveness using tokenization, Type-Token Ratio, compression-based metrics, and n-gram repetition.

# %% [markdown]
# #### 1. Load data

# %%
import pandas as pd
df = pd.read_csv('2025_data_lyrics_og.csv')
df.head()
# Out:
#    idx  year  sf_num  to_country            performer           song  \
# 0    0  2025     1.0     Albania  Shkodra Elektronike          Zjerm
# 1    1  2025     2.0     Armenia                 Parg       Survivor
# 2    2  2025     2.0   Australia                Go-Jo  Milkshake Man
# 3    3  2025     2.0     Austria                   JJ    Wasted Love
# 4    4  2025     1.0  Azerbaijan             Mamagama     Run With U
#
#    running_final  running_sf  LY_SF_reciprocation  LY_SF_vote  \
# 0            NaN        12.0                 0.10    0.210526
# 1            NaN         5.0                 0.50    1.000000
# 2            NaN         1.0                 0.35    0.722222
# 3            NaN         6.0                 0.50    0.789474
# 4            NaN        10.0                 0.20    0.333333
#
#    LY_final_reciprocation  LY_final_vote  \
# 0                    0.00       0.000000
# 1                    0.60       0.783784
# 2                    0.00       0.000000
# 3                    0.15       0.135135
# 4                    0.00       0.000000
#
#                                               lyrics  \
# 0  "Në këtë minutë, në këtë çast no paranoia Pas ...
# 1  "Survivor\nI got my bad shades on Jet-black am...
# 2  "Come and take a sip from my special cup I hea...
# 3  "I'm an ocean of love And you're scared of wat...
# 4  "Rhythm pulls me out Don't know where to start...
#
#                               lyrics_eng_translation  \
# 0  At this minute, at this moment, no more parano...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   lyrics_all_english  lyrics_english  \
# 0  At this minute, at this moment, no more parano...               0
# 1  "Survivor\nI got my bad shades on Jet-black am...               1
# 2  "Come and take a sip from my special cup I hea...               1
# 3  "I'm an ocean of love And you're scared of wat...               1
# 4  "Rhythm pulls me out Don't know where to start...               1
#
#    lyrics_english_mix                                         lyrics_url
# 0                   0  https://eurovisionworld.com/eurovision/2025/al...
# 1                   0  https://eurovisionworld.com/eurovision/2025/ar...
# 2                   0  https://eurovisionworld.com/eurovision/2025/au...
# 3                   0  https://eurovisionworld.com/eurovision/2025/au...
# 4                   0  https://eurovisionworld.com/eurovision/2025/az...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   idx                     37 non-null     int64
#  1   year                    37 non-null     int64
#  2   sf_num                  31 non-null     float64
#  3   to_country              37 non-null     object
#  4   performer               37 non-null     object
#  5   song                    37 non-null     object
#  6   running_final           1 non-null      float64
#  7   running_sf              31 non-null     float64
#  8   LY_SF_reciprocation     37 non-null     float64
#  9   LY_SF_vote              37 non-null     float64
#  10  LY_final_reciprocation  37 non-null     float64
#  11  LY_final_vote           37 non-null     float64
#  12  lyrics                  37 non-null     object
#  13  lyrics_eng_translation  23 non-null     object
#  14  lyrics_all_english      37 non-null     object
#  15  lyrics_english          37 non-null     int64
#  16  lyrics_english_mix      37 non-null     int64
#  17  lyrics_url              37 non-null     object
# dtypes: float64(7), int64(4), object(7)
# memory usage: 5.3+ KB

# %% [markdown]
# #### 2. Text pre-processing
# Cleaning and Tokenisation

# %%
df['lyrics']
# Out:
# 0     "Në këtë minutë, në këtë çast no paranoia Pas ...
# 1     "Survivor\nI got my bad shades on Jet-black am...
# 2     "Come and take a sip from my special cup I hea...
# 3     "I'm an ocean of love And you're scared of wat...
# 4     "Rhythm pulls me out Don't know where to start...
# 5     "Strobe lights, gettin' lost in your eyes Cott...
# 6     "It's cool now in the kitchen That happens whe...
# 7     "I've got golden locks and eyes so captivating...
# 8     "Blow me a kiss goodbye I don't want my tears ...
# 9     "You show me more More than meets the eye You ...
# 10    "Mi amore Mi amore Espresso macchiato, macchia...
# 11    "(Ich komme) On yö, sydän lyö Hän loveen lanke...
# 12    "Y'a plus d'amants Y'a plus de lits Finalement...
# 13    "(Mze, tsa)\nTavisupleba\n(Ani da bani, gani d...
# 14    "Ich ballalalalalalaler Löcher in die Nacht St...
# 15    "Asteri mou Asteri mou\nGlykia mou mana mi mou...
# 16    "Róandi hér, róandi þar Róa í gegnum öldurnar ...
# 17    "(Ready for take off)\nYou have probably heard...
# 18    "And even if you say goodbye You'll never go a...
# 19    "Volevo essere un duro Che non gli importa del...
# 20    "Bur man, bur man, bur man, bur man Nevar mani...
# 21    "Tuščios kalbos tik didina ugnį Dega namai Jie...
# 22    "Si tu n'vois en moi qu'une poupée parfaite Qu...
# 23    "I've got a secret you should know Come a litt...
# 24    "Budi se noć koja je kriva Umorne oči trlja be...
# 25    "C'est la vie She sang to me Je me rappelle J'...
# 26    "Golden girl dressed in ice A heart as dark as...
# 27    "(They call me Gaia)\nRanisz moje serce Ty Któ...
# 28    "Conto os dias para mim Com a mala arrumada Já...
# 29    "Mamma stasera non ritorno Ma sicuro finisco i...
# 30    "Neka bude mi To zadnja večera Nek oko Kerbera...
# 31    "Our baby boy Was crawling in the living room ...
# 32    "Desde que era bien pequeña Antes de saber and...
# 33    "Nåjaa\nKlockon slår, nu ere dags All bekymber...
# 34    "Mes yeux candides découvrent le monde D'une f...
# 35    "Zaide-zaidesh i do mene, moia ptashka Krylamy...
# 36    "Someone lost a shoe I'm still in last night's...
# Name: lyrics, dtype: object

# %%
### CLEAN TEXT
import re

def clean_lyrics(text):
    """
    Cleans the provided text by:
    - Replacing newline characters and escaped newlines with spaces
    - Removing punctuation and special characters
    - Converting text to lowercase
    """
    # Replace newline characters with spaces
    text = re.sub(r'\\n|\n', ' ', text)
    
    # Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)
    
    # Convert text to lowercase
    text = text.lower()
    
    return text

# %%
df['cleaned_lyrics'] = df['lyrics'].apply(clean_lyrics)

# %%
### TOKENISE
import nltk

# Ensure that the NLTK tokenizers are downloaded
nltk.download('punkt')

def tokenize_lyrics(text):
    """
    Tokenizes the text into individual words using NLTK's word_tokenize.
    """
    tokens = nltk.word_tokenize(text)
    return tokens
# Out:
# [nltk_data] Downloading package punkt to /Users/kasia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['lyrics_tokens'] = df['cleaned_lyrics'].apply(tokenize_lyrics)

# %% [markdown]
# #### 3. Vocabulary Wealth
# Calculate type-token ratio

# %%
def analyze_lyrics(lyrics):   
    # Count all words
    total_words = len(lyrics)
    
    # Count all unique words
    unique_words = len(set(lyrics))
    
    # Calculate Type-Token Ratio (TTR)
    ttr = unique_words / total_words if total_words > 0 else 0
    
    return {
        'total_words': total_words,
        'unique_words': unique_words,
        'type_token_ratio': ttr
    }

# %%
# Apply the analysis function to the 'Lyrics' column
df_analysis = df['lyrics_tokens'].apply(lambda x: pd.Series(analyze_lyrics(x)))

# Join the analysis results with the original DataFrame
df = pd.concat([df, df_analysis], axis=1)

# %%
df.head()
# Out:
#    idx  year  sf_num  to_country            performer           song  \
# 0    0  2025     1.0     Albania  Shkodra Elektronike          Zjerm
# 1    1  2025     2.0     Armenia                 Parg       Survivor
# 2    2  2025     2.0   Australia                Go-Jo  Milkshake Man
# 3    3  2025     2.0     Austria                   JJ    Wasted Love
# 4    4  2025     1.0  Azerbaijan             Mamagama     Run With U
#
#    running_final  running_sf  LY_SF_reciprocation  LY_SF_vote  ...  \
# 0            NaN        12.0                 0.10    0.210526  ...
# 1            NaN         5.0                 0.50    1.000000  ...
# 2            NaN         1.0                 0.35    0.722222  ...
# 3            NaN         6.0                 0.50    0.789474  ...
# 4            NaN        10.0                 0.20    0.333333  ...
#
#                               lyrics_eng_translation  \
# 0  At this minute, at this moment, no more parano...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   lyrics_all_english lyrics_english  \
# 0  At this minute, at this moment, no more parano...              0
# 1  "Survivor\nI got my bad shades on Jet-black am...              1
# 2  "Come and take a sip from my special cup I hea...              1
# 3  "I'm an ocean of love And you're scared of wat...              1
# 4  "Rhythm pulls me out Don't know where to start...              1
#
#   lyrics_english_mix                                         lyrics_url  \
# 0                  0  https://eurovisionworld.com/eurovision/2025/al...
# 1                  0  https://eurovisionworld.com/eurovision/2025/ar...
# 2                  0  https://eurovisionworld.com/eurovision/2025/au...
# 3                  0  https://eurovisionworld.com/eurovision/2025/au...
# 4                  0  https://eurovisionworld.com/eurovision/2025/az...
#
#                                       cleaned_lyrics  \
# 0  në këtë minutë në këtë çast no paranoia pas sh...
# 1  survivor i got my bad shades on jetblack am in...
# 2  come and take a sip from my special cup i hear...
# 3  im an ocean of love and youre scared of water ...
# 4  rhythm pulls me out dont know where to start y...
#
#                                        lyrics_tokens total_words unique_words  \
# 0  [në, këtë, minutë, në, këtë, çast, no, paranoi...       241.0        134.0
# 1  [survivor, i, got, my, bad, shades, on, jetbla...       315.0        122.0
# 2  [come, and, take, a, sip, from, my, special, c...       365.0        110.0
# 3  [im, an, ocean, of, love, and, youre, scared, ...       145.0         66.0
# 4  [rhythm, pulls, me, out, dont, know, where, to...       256.0        110.0
#
#   type_token_ratio
# 0         0.556017
# 1         0.387302
# 2         0.301370
# 3         0.455172
# 4         0.429688
#
# [5 rows x 23 columns]

# %% [markdown]
# #### 4. Repetitiveness
#
# Compression size reduction and n-gram repetitiveness

# %%
def LZW_compress(input_string):
    # Initialize the dictionary with single characters available in the input string
    # Ensures all characters in input are covered, including unicode characters
    dictionary = {chr(i): i for i in range(256)}
    current_string = ""
    codes = []
    code = 256  # Starting code for new entries
    
    # Extend the dictionary to include any unique characters in the input string not already in the dictionary
    for character in set(input_string):
        if character not in dictionary:
            dictionary[character] = code
            code += 1

    for character in input_string:
        new_string = current_string + character
        if new_string in dictionary:
            current_string = new_string
        else:
            codes.append(dictionary[current_string])
            dictionary[new_string] = code
            code += 1
            current_string = character
    if current_string:
        codes.append(dictionary[current_string])
    return codes, len(dictionary)

def calculate_compression(original, compressed):
    original_size = len(original) * 8  # Assuming 8 bits per character
    compressed_size = len(compressed) * 12  # Assuming 12 bits per LZW code
    reduction = ((original_size - compressed_size) / original_size) 
    return reduction

def apply_compression_and_calculate_reduction(row):
    compressed_lyrics, _ = LZW_compress(row['cleaned_lyrics'])
    reduction_percentage = calculate_compression(row['cleaned_lyrics'], compressed_lyrics)
    return reduction_percentage

# %%
df['compression_size_reduction'] = df.apply(apply_compression_and_calculate_reduction, axis=1)

# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter
import numpy as np
import pandas as pd
import nltk

# Ensure you have the necessary NLTK data
nltk.download('punkt')

def calculate_avg_ngram_repetitiveness(lyrics, n_values=[2,3,4,5,6,7,8,9,10]):
    
    tokens = word_tokenize(lyrics)
    
    repetitiveness_scores = []
    
    #print(len(tokens))
    for n in n_values:
        if len(tokens) < n:
            # If there are fewer tokens than the size of the n-gram, skip this n-value
            continue
            
        # Generate N-grams from the list of tokens
        n_grams = list(ngrams(tokens, n))
        #print(n_grams)
        # Count the frequency of each N-gram
        n_gram_counts = Counter(n_grams)
        #print(n_gram_counts)
        
        # Calculate repetitiveness: proportion of N-grams appearing more than once
        total_n_grams = len(n_grams)
        #print(n, " total: ", total_n_grams)
        repeated_n_grams = sum(count for count in n_gram_counts.values() if count > 1)
        #print(n, " repeated: ", repeated_n_grams)
        
        if total_n_grams > 0:  # Check to prevent division by zero
            repetitiveness_score = repeated_n_grams / total_n_grams
            repetitiveness_scores.append(repetitiveness_score)
    #print(repetitiveness_scores)
    # Calculate the average repetitiveness score across all n-gram sizes
    avg_repetitiveness = np.mean(repetitiveness_scores) if repetitiveness_scores else 0
    
    return avg_repetitiveness
# Out:
# [nltk_data] Downloading package punkt to /Users/kasia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['n_gram_repetitiveness'] = df['cleaned_lyrics'].apply(lambda x: calculate_avg_ngram_repetitiveness(x, n_values=[2,3,4,5,6,7,8,9,10]))

# %%
df
# Out:
#     idx  year  sf_num      to_country            performer  \
# 0     0  2025     1.0         Albania  Shkodra Elektronike
# 1     1  2025     2.0         Armenia                 Parg
# 2     2  2025     2.0       Australia                Go-Jo
# 3     3  2025     2.0         Austria                   JJ
# 4     4  2025     1.0      Azerbaijan             Mamagama
# 5     5  2025     1.0         Belgium        Red Sebastian
# 6     6  2025     1.0         Croatia        Marko Bošnjak
# 7     7  2025     1.0          Cyprus            Theo Evan
# 8     8  2025     2.0         Czechia               Adonxs
# 9     9  2025     2.0         Denmark               Sissal
# 10   10  2025     1.0         Estonia           Tommy Cash
# 11   11  2025     2.0         Finland         Erika Vikman
# 12   12  2025     NaN          France               Louane
# 13   13  2025     2.0         Georgia     Mariam Shengelia
# 14   14  2025     NaN         Germany         Abor & Tynna
# 15   15  2025     2.0          Greece              Klavdia
# 16   16  2025     1.0         Iceland                  Væb
# 17   17  2025     2.0         Ireland                 Emmy
# 18   18  2025     2.0          Israel        Yuval Raphael
# 19   19  2025     NaN           Italy          Lucio Corsi
# 20   20  2025     2.0          Latvia          Tautumeitas
# 21   21  2025     2.0       Lithuania             Katarsis
# 22   22  2025     2.0      Luxembourg          Laura Thorn
# 23   23  2025     2.0           Malta        Miriana Conte
# 24   24  2025     2.0      Montenegro           Nina Žižić
# 25   25  2025     1.0     Netherlands               Claude
# 26   26  2025     1.0          Norway      Kyle Alessandro
# 27   27  2025     1.0          Poland  Justyna Steczkowska
# 28   28  2025     1.0        Portugal                 Napa
# 29   29  2025     1.0      San Marino          Gabry Ponte
# 30   30  2025     2.0          Serbia                Princ
# 31   31  2025     1.0        Slovenia               Klemen
# 32   32  2025     NaN           Spain               Melody
# 33   33  2025     1.0          Sweden                  KAJ
# 34   34  2025     NaN     Switzerland               Zoë Më
# 35   35  2025     1.0         Ukraine            Ziferblat
# 36   36  2025     NaN  United Kingdom      Remember Monday
#
#                              song  running_final  running_sf  \
# 0                           Zjerm            NaN        12.0
# 1                        Survivor            NaN         5.0
# 2                   Milkshake Man            NaN         1.0
# 3                     Wasted Love            NaN         6.0
# 4                      Run With U            NaN        10.0
# 5                   Strobe Lights            NaN         9.0
# 6                     Poison Cake            NaN        14.0
# 7                             Shh            NaN        15.0
# 8               Kiss Kiss Goodbye            NaN        12.0
# 9                   Hallucination            NaN        11.0
# 10             Espresso macchiato            NaN         4.0
# 11                      Ich komme            NaN        16.0
# 12                          Maman            NaN         NaN
# 13                        Freedom            NaN        10.0
# 14                         Baller            NaN         NaN
# 15                     Asteromata            NaN         7.0
# 16                            Róa            NaN         1.0
# 17                    Laika Party            NaN         3.0
# 18              New Day Will Rise            NaN        14.0
# 19          Volevo essere un duro            NaN         NaN
# 20                  Bur man laimi            NaN         4.0
# 21                      Tavo akys            NaN         8.0
# 22         La poupée monte le son            NaN        13.0
# 23                        Serving            NaN         9.0
# 24                     Dobrodošli            NaN         2.0
# 25                   C'est La Vie            NaN        13.0
# 26                        Lighter            NaN         8.0
# 27                           Gaja            NaN         2.0
# 28                      Deslocado            NaN         7.0
# 29                 Tutta l'Italia            NaN        11.0
# 30                           Mila            NaN        15.0
# 31  How Much Time Do We Have Left            NaN         3.0
# 32                       Esa diva            NaN         NaN
# 33                Bara bada bastu            NaN         6.0
# 34                         Voyage           19.0         NaN
# 35                   Bird of Pray            NaN         5.0
# 36   What The Hell Just Happened?            NaN         NaN
#
#     LY_SF_reciprocation  LY_SF_vote  ...  lyrics_english  lyrics_english_mix  \
# 0                  0.10    0.210526  ...               0                   0
# 1                  0.50    1.000000  ...               1                   0
# 2                  0.35    0.722222  ...               1                   0
# 3                  0.50    0.789474  ...               1                   0
# 4                  0.20    0.333333  ...               1                   0
# 5                  0.25    0.368421  ...               1                   0
# 6                  0.50    1.000000  ...               1                   0
# 7                  0.40    0.722222  ...               1                   0
# 8                  0.40    0.736842  ...               1                   0
# 9                  0.35    0.473684  ...               1                   0
# 10                 0.45    0.842105  ...               0                   1
# 11                 0.35    0.722222  ...               0                   0
# 12                 0.00    0.000000  ...               0                   0
# 13                 0.30    0.684211  ...               0                   0
# 14                 0.00    0.000000  ...               0                   0
# 15                 0.45    0.842105  ...               0                   0
# 16                 0.05    0.111111  ...               0                   0
# 17                 0.50    1.000000  ...               1                   0
# 18                 0.50    0.947368  ...               0                   1
# 19                 0.00    0.000000  ...               0                   0
# 24  [budi, se, noć, koja, je, kriva, umorne, oči, ...        156.0
# 25  [cest, la, vie, she, sang, to, me, je, me, rap...        227.0
# 26  [golden, girl, dressed, in, ice, a, heart, as,...        289.0
# 27  [they, call, me, gaia, ranisz, moje, serce, ty...        110.0
# 28  [conto, os, dias, para, mim, com, a, mala, arr...        209.0
# 29  [mamma, stasera, non, ritorno, ma, sicuro, fin...        239.0
# 30  [neka, bude, mi, to, zadnja, večera, nek, oko,...        155.0
# 31  [our, baby, boy, was, crawling, in, the, livin...        282.0
# 32  [desde, que, era, bien, pequeña, antes, de, sa...        251.0
# 33  [nåjaa, klockon, slår, nu, ere, dags, all, bek...        329.0
# 34  [mes, yeux, candides, découvrent, le, monde, d...        213.0
# 35  [zaidezaidesh, i, do, mene, moia, ptashka, kry...        127.0
# 36  [someone, lost, a, shoe, im, still, in, last, ...        244.0
#
#     unique_words type_token_ratio compression_size_reduction  \
# 0          134.0         0.556017                   0.264637
# 1          122.0         0.387302                   0.335901
# 2          110.0         0.301370                   0.406426
# 3           66.0         0.455172                   0.257532
# 4          110.0         0.429688                   0.289267
# 5           76.0         0.410811                   0.246926
# 6          111.0         0.426923                   0.321663
# 7           76.0         0.279412                   0.335052
# 8           82.0         0.369369                   0.333185
# 9           77.0         0.461078                   0.313112
# 10          75.0         0.416667                   0.362022
# 11          99.0         0.412500                   0.347566
# 12          75.0         0.396825                   0.309451
# 13         105.0         0.714286                   0.181185
# 14         114.0         0.327586                   0.392327
# 15          59.0         0.479675                   0.262443
# 16          94.0         0.323024                   0.357438
# 17          95.0         0.399160                   0.303017
# 18         122.0         0.445255                   0.262595
# 19         129.0         0.496154                   0.289116
# 20          26.0         0.106996                   0.583510
# 21          36.0         0.450000                   0.195279
# 22         145.0         0.379581                   0.369659
# 23          95.0         0.319865                   0.330520
# 24          78.0         0.500000                   0.242167
# 25          72.0         0.317181                   0.358871
# 26         111.0         0.384083                   0.296552
# 27          83.0         0.754545                   0.069652
# 28          90.0         0.430622                   0.271992
# 29         118.0         0.493724                   0.339192
# 30          57.0         0.367742                   0.273217
# 31         115.0         0.407801                   0.303412
# 32         103.0         0.410359                   0.277868
# 33          83.0         0.252280                   0.443709
# 34          77.0         0.361502                   0.340278
# 35          64.0         0.503937                   0.179039
# 36         119.0         0.487705                   0.268638
#
#    n_gram_repetitiveness
# 0               0.411685
# 1               0.368144
# 2               0.520278
# 3               0.341697
# 4               0.427451
# 5               0.692625
# 6               0.408045
# 7               0.617678
# 8               0.579693
# 9               0.243982
# 10              0.370009
# 11              0.321514
# 12              0.428437
# 13              0.009909
# 14              0.684582
# 15              0.305887
# 16              0.590121
# 17              0.650716
# 18              0.349660
# 19              0.357435
# 20              0.904376
# 21              0.477242
# 22              0.400143
# 23              0.523159
# 24              0.225440
# 25              0.570708
# 26              0.516818
# 27              0.025579
# 28              0.445792
# 29              0.387567
# 30              0.623589
# 31              0.417835
# 32              0.567883
# 33              0.692067
# 34              0.505448
# 35              0.332283
# 36              0.307532
#
# [37 rows x 25 columns]

# %%
#save csv file
#df.to_csv('2025data_lyrics.csv')
